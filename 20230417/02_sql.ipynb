# %% [markdown]
# # mysql과 python 연동
# 1. 라이브러리 설치
# 2. sql 서버의 정보를 등록
# 3. sql 서버에 접속
# 4. sql 쿼리문을 이용하여 데이터를 CRUD 작업

# %%
# pymysql 설치
# !pip3 install pymysql
# Out:
# Requirement already satisfied: pymysql in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.0.3)

# %%
import pymysql

# %%
# sql 서버의 정보를 입력
_db = pymysql.connect(
    user = 'root',
    # password = '1234',
    host = 'localhost',
    db = 'ubion7',
    port = 3306
)

# %%
# cursor 변수 생성
# sql 쿼리문을 실행시키기 위한 필수 변수
# DictCursor는 sql 쿼리문이 실행되고 나온 데이터를 딕셔너리 형태로 받는다.
cursor = _db.cursor(pymysql.cursors.DictCursor)

# %%
sql = """
    select
    *
    from
    user_info
"""

cursor.execute(sql)
# Out:
# 8

# %%
result = cursor.fetchall()

# %%
import pandas as pd

# %%
pd.DataFrame(result)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1  test10      1223    test10  01077777777            1
# 2   test2      1234     test2  01011111111            2
# 3   test3      1111     test3  01099999999            2
# 4   test4      1234     test4  01011111111            1
# 5   test5      1234     test5  01011110000            1
# 6   test6      5678     test6  01011112222            2
# 7   test7      5558     test7  01022223333            1

# %%
sql = """
    select
    *
    from
    example
"""

cursor.execute(sql)
result = cursor.fetchall()
df = pd.DataFrame(result)
df
# Out:
#   Name  Gender          Phone
# 0    A    male  010-1234-5678
# 1    B  female  010-1234-5679
# 2    C    male  010-1234-5680
# 3    D  female  010-1234-5681
# 4    E    male  010-1234-5682
# 5    F  female  010-1234-5683
# 6    G    male  010-1234-5684
# 7    H  female  010-1234-5685
# 8    I    male  010-1234-5686
# 9    J  female  010-1234-5687

# %%
sql = """
    insert into
    user_info
    values
    ("test9", "1234", "test5", "01011110000", 1)
"""

cursor.execute(sql)
# Out:
# 1

# %%
_db.commit()

# %% [markdown]
# ### sql 함수화
# 1. 첫 번째 함수
#     - 매개변수를 1개(sql 쿼리문)
#     - sql 쿼리문을 실행하고 결과를 데이터프레임으로 변경하여 리턴
# 2. 두 번째 함수
#     - 매개변수 1개(sql 쿼리문)
#     - sql 쿼리문을 실행하고 데이터베이스를 변경
# 3. 세 번째 함수
#     - 1번 함수와 2번 함수를 하나의 함수에서 실행이 될 수 있도록 생성

# %%
# 첫번째 함수
def sql_select(sql):
    # 쿼리문 실행
    cursor.execute(sql)
    # 쿼리문에 대한 결과
    result = cursor.fetchall()
    #df = pd.DataFrame(result)
    return pd.DataFrame(result)
    #return df

# %%
sql = """
    select
    *
    from
    user_info
"""

sql_select(sql)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1  test10      1223    test10  01077777777            1
# 2   test2      1234     test2  01011111111            2
# 3   test3      1111     test3  01099999999            2
# 4   test4      1234     test4  01011111111            1
# 5   test5      1234     test5  01011110000            1
# 6   test6      5678     test6  01011112222            2
# 7   test7      5558     test7  01022223333            1
# 8   test9      1234     test5  01011110000            1

# %%
# 두번째 함수
def _sql(sql, values):
    cursor.execute(sql, values)
    _db.commit()

# %%
sql = """
        insert into
        user_info
        values
        (%s, %s, %s, %s, %s)
    """

values = ["test11", "1223", "test10", "01077777777", 1]
_sql(sql, values)

# %%
sql = """
    select
    *
    from
    user_info
"""

sql.find("select")
# Out:
# 5

# %%
def sql_query(sql):
    # if (sql.find("select") != -1) and (sql.find("select") < 10):
    if (sql.replace('\n', '').strip().startswith('select')):
        cursor.execute(sql)
        result = cursor.fetchall()
        result = pd.DataFrame(result)
    else:
        cursor.execute(sql)
        _db.commit()
        result = "Query OK"
    return result

# %%
sql = """
    select
    *
    from
    user_info
"""

sql_query(sql)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1  test10      1223    test10  01077777777            1
# 2  test11      1223    test10  01077777777            1
# 3   test2      1234     test2  01011111111            2
# 4   test3      1111     test3  01099999999            2
# 5   test4      1234     test4  01011111111            1
# 6   test5      1234     test5  01011110000            1
# 7   test6      5678     test6  01011112222            2
# 8   test7      5558     test7  01022223333            1
# 9   test9      1234     test5  01011110000            1

# %%
sql = """
    delete
    from
    user_info
    where
    user_id = %s
"""

values = ['test10']

sql_query(sql, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       1 sql = """
#       2     delete
#       3     from
#    (...)
#       6     user_id = %s
#       7 """
#       9 values = ['test10']
# ---> 11 sql_query(sql, values)
#
# TypeError: sql_query() takes 1 positional argument but 2 were given

# %%
import mod_sql
import imp
imp.reload(mod_sql)
# Out:
# <module 'mod_sql' from '/Users/taewon/Documents/GitHub/python_01/20230417/mod_sql/__init__.py'>

# %%
test = mod_sql.Database(
    _host= 'localhost', 
    _user= 'root',  
    _db = 'ubion7', 
    _port = 3306)

# %%
sql = """
    select 
    * 
    from 
    user_info
"""
test.sql_query(sql)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1  test10      1223    test10  01077777777            1
# 2  test11      1223    test10  01077777777            1
# 3   test2      1234     test2  01011111111            2
# 4   test3      1111     test3  01099999999            2
# 5   test4      1234     test4  01011111111            1
# 6   test5      1234     test5  01011110000            1
# 7   test6      5678     test6  01011112222            2
# 8   test7      5558     test7  01022223333            1
# 9   test9      1234     test5  01011110000            1

# %%
sql = """
    select 
    `Name` as '이름', 
    `Phone` as '휴대폰번호'
    from 
    example 
    where 
    `Gender` = %s
    limit 3
"""
values = ['female']
test.sql_query(sql, values)
# Out:
#   이름          휴대폰번호
# 0  B  010-1234-5679
# 1  D  010-1234-5681
# 2  F  010-1234-5683

# %%
sql = """
    select 
    * 
    from 
    user_info
"""

test.sql_query(sql)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1  test10      1223    test10  01077777777            1
# 2  test11      1223    test10  01077777777            1
# 3   test2      1234     test2  01011111111            2
# 4   test3      1111     test3  01099999999            2
# 5   test4      1234     test4  01011111111            1
# 6   test5      1234     test5  01011110000            1
# 7   test6      5678     test6  01011112222            2
# 8   test7      5558     test7  01022223333            1
# 9   test9      1234     test5  01011110000            1

# %%
sql = """
    insert into 
    user_info 
    values 
    ("test11111", "1234", "test", "01011111111", 1)
"""

test.sql_query(sql)
# Out:
# 'Query OK'

# %%
sql =  """
    select 
    createDt as '등록일시', 
    deathCnt as '사망자', 
    decideCnt as '감염자' 
    from 
    corona
"""
test.sql_query(sql)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[46], line 9
#       1 sql =  """
#       2     select
#       3     createDt as '등록일시',
#    (...)
#       7     corona
#       8 """
# ----> 9 test.sql_query(sql)
#
# File ~/Documents/GitHub/python_01/20230417/mod_sql/__init__.py:18, in Database.sql_query(self, sql, values)
#      15 def sql_query(self, sql, values = []):
#      16     # if (sql.find("select") != -1) and (sql.find('select') < 10):
#      17     if (sql.replace('\n', '').strip().startswith('select')):
# ---> 18         self.cursor.execute(sql, values)
#      19         result = self.cursor.fetchall()
#      20         result = pd.DataFrame(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     546 if isinstance(sql, str):
#     547     sql = sql.encode(self.encoding, "surrogateescape")
# --> 548 self._execute_command(COMMAND.COM_QUERY, sql)
#     549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/connections.py:797, in Connection._execute_command(self, command, sql)
#     792 """
#     793 :raise InterfaceError: If the connection is closed.
#     794 :raise ValueError: If no username was specified.
#     795 """
#     796 if not self._sock:
# --> 797     raise err.InterfaceError(0, "")
#     799 # If the last query was unbuffered, make sure it finishes before
#     800 # sending new commands
#     801 if self._result is not None:
#
# InterfaceError: (0, '')

# %%
test.sql_close()

# %%
df =pd.read_csv("../csv/corona.csv")

# %%
df = df[['createDt', 'deathCnt', 'decideCnt']]
df.head()
# Out:
#                   createDt  deathCnt  decideCnt
# 0  2022-06-08 09:09:05.982     24305   18188200
# 1  2022-06-07 09:09:00.897     24299   18174842
# 2  2022-06-06 09:00:06.734     24279   18168670
# 3  2022-06-05 08:53:19.426     24258   18163648
# 4  2022-06-04 08:56:49.219     24238   18153814

# %%
df.columns = ['등록일시', '사망자', '감염자']
df.head()
# Out:
#                       등록일시    사망자       감염자
# 0  2022-06-08 09:09:05.982  24305  18188200
# 1  2022-06-07 09:09:00.897  24299  18174842
# 2  2022-06-06 09:00:06.734  24279  18168670
# 3  2022-06-05 08:53:19.426  24258  18163648
# 4  2022-06-04 08:56:49.219  24238  18153814

# %%
sql = """
    select 
    `Country` as '국가', 
    `Units Sold` as '판매개수', 
    `Unit Price` as '가격', 
    `Unit Cost` as '원가', 
    (`Units Sold` * `Unit Price`) as '총수익', 
    (`Units Sold` * `Unit Cost`) as '총비용', 
    (`Units Sold` * `Unit Price` - `Units Sold` * `Unit Cost`) as '총이윤'
    from 
    `Sales Records`
"""
test.sql_query(sql)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[45], line 13
#       1 sql = """
#       2     select
#       3     `Country` as '국가',
#    (...)
#      11     `Sales Records`
#      12 """
# ---> 13 test.sql_query(sql)
#
# File ~/Documents/GitHub/python_01/20230417/mod_sql/__init__.py:18, in Database.sql_query(self, sql, values)
#      15 def sql_query(self, sql, values = []):
#      16     # if (sql.find("select") != -1) and (sql.find('select') < 10):
#      17     if (sql.replace('\n', '').strip().startswith('select')):
# ---> 18         self.cursor.execute(sql, values)
#      19         result = self.cursor.fetchall()
#      20         result = pd.DataFrame(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     546 if isinstance(sql, str):
#     547     sql = sql.encode(self.encoding, "surrogateescape")
# --> 548 self._execute_command(COMMAND.COM_QUERY, sql)
#     549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymysql/connections.py:797, in Connection._execute_command(self, command, sql)
#     792 """
#     793 :raise InterfaceError: If the connection is closed.
#     794 :raise ValueError: If no username was specified.
#     795 """
#     796 if not self._sock:
# --> 797     raise err.InterfaceError(0, "")
#     799 # If the last query was unbuffered, make sure it finishes before
#     800 # sending new commands
#     801 if self._result is not None:
#
# InterfaceError: (0, '')
