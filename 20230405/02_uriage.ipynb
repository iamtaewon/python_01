# %%
import pandas as pd

# %% [markdown]
# 1. csv폴더에서 uriage.csv 파일 로드
# 2. purchase_date 컬럼의 데이터를 시계열데이터 변경
# 3. item_name의 데이터의 모든 문자열을 대문자로 변경
# 4. item_name의 데이터의 공백을 모두 삭제
# 5. item_name을 기준으로 오름차순 정렬
# 6. 인덱스를 초기화
# 7. 결측치를 채우는 작업
#     - item_price 컬럼에 결측치가 존재
#     - 상품 A인 경우 결측치는 상품 A의 item_price중 결측치가 아닌 값으로 치환
#     - 위의 작업을 상품 A부터 상품 Z까지 반복 작업

# %%
uriage = pd.read_csv('../csv/uriage.csv')

# %%
uriage.info() # -> 데이터의 구성을 항상 미리 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   purchase_date  2999 non-null   object
#  1   item_name      2999 non-null   object
#  2   item_price     2612 non-null   float64
#  3   customer_name  2999 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 93.8+ KB

# %%
uriage.isna().sum()
# Out:
# purchase_date      0
# item_name          0
# item_price       387
# customer_name      0
# dtype: int64

# %%
# 시계열 데이터로 데이터의 형태를 변경
# pd.to_datetime(변경할 데이터, format = "")
t = '2023-04-05'
pd.to_datetime(t, format="%Y-%m-%d")
# t = '2023-04-05'
# pd.to_datetime(t) --> 안 적어도 같음(이미 구분이 되어있기 때문에)
# Out:
# Timestamp('2023-04-05 00:00:00')

# %%
t = '04/05/05'
pd.to_datetime(t)
# 맨 뒤 값이 연도로 출력되게 함
# Out:
# Timestamp('2005-04-05 00:00:00')

# %%
t = '04/05/05'
pd.to_datetime(t, format="%y/%m/%d")
# format을 이용해서 맨 앞 값이 연도로 출력되게 할 수도 있음(소문자 y)
# Out:
# Timestamp('2004-05-05 00:00:00')

# %%
# purchase_date 컬럼을 시계열로 변경
pd.to_datetime(uriage['purchase_date'],
               format = '%Y-%m-%d %H:%M')
# Out:
# 0      2019-06-13 18:02:00
# 1      2019-07-13 13:05:00
# 2      2019-05-11 19:42:00
# 3      2019-02-12 23:40:00
# 4      2019-04-22 03:09:00
#                ...
# 2994   2019-02-15 02:56:00
# 2995   2019-06-22 04:03:00
# 2996   2019-03-29 11:14:00
# 2997   2019-07-14 12:56:00
# 2998   2019-07-21 00:31:00
# Name: purchase_date, Length: 2999, dtype: datetime64[ns]

# %%
# purchase_date 컬럼을 시계열로 변경
uriage['purchase_date'] = pd.to_datetime(df['purchase_date'],
                                     format = '%Y-%m-%d %H:%M')

# %%
# 원본데이터를 생성
origin_data = uriage.copy()

# %%
# item_name 컬럼의 데이터를 모두 대문자로 변경
# upper() : 문자열을ㄹ 모두 대문자로 변환
# str.upper() 를 사용하여 문자열을 대문자로 변경하는 방식

uriage['item_name'] = uriage['item_name'].str.upper()

# %%
# apply() 함수를 이용하여 글자를 모두 소문자로 변경
# apply()는 Series형태데이터.apply(함수) -->
# Series의 데이터들을 하나씩 함수안에 넣어서 결과값으로
# 새로운 Series 형태의 데이터를 생성

def change(x):
    result = x.lower()
    return result

uriage['item_name'] = uriage['item_name'].apply(change)

# %%
# strip() 함수만으로는 공백이 전부 지워지지 않음
uriage['item_name'].str.strip()
# Out:
# 0         상품a
# 1       상 품 s
# 2       상 품 a
# 3         상품z
# 4         상품a
#         ...
# 2994      상품y
# 2995      상품m
# 2996      상품q
# 2997      상품h
# 2998      상품d
# Name: item_name, Length: 2999, dtype: object

# %%
# apply(lambda 함수)
uriage['item_name'] = uriage['item_name'].apply(lambda x : x.upper())

# %%
def change(x):
    print(x)
    return x

uriage.apply(change)
# Out:
# 0      2019-01-02 13:26:00
# 1      2019-03-02 15:38:00
# 2      2019-03-02 01:53:00
# 3      2019-03-04 16:39:00
# 4      2019-05-03 01:15:00
#                ...
# 2994   2019-04-24 14:12:00
# 2995   2019-02-28 15:15:00
# 2996   2019-02-18 08:16:00
# 2997   2019-06-05 13:37:00
# 2998   2019-05-16 04:45:00
# Name: purchase_date, Length: 2999, dtype: datetime64[ns]
# 0         상품A
# 1       상 품 S
# 2       상 품 A
# 3         상품Z
# 4         상품A
#         ...
# 2994      상품Y
# 2995      상품M
# 2996      상품Q
# 2997      상품H
# 2998      상품D
# Name: item_name, Length: 2999, dtype: object
# 0        100.0
# 1          NaN
# 2          NaN
# 3       2600.0
# 4          NaN
#          ...
# 2994    2500.0
# 2995    1300.0
# 2996       NaN
# 2997       NaN
# 2998     400.0
# Name: item_price, Length: 2999, dtype: float64
# 0       김가온
# 1       김우찬
# 2       김유찬
# 3       김재현
# 4       김강현
#        ...
# 2994    김정민
# 2995    김재원
# 2996    김지율
# 2997    김승주
# 2998    정준기
# Name: customer_name, Length: 2999, dtype: object
#            purchase_date item_name  item_price customer_name
# 0    2019-01-02 13:26:00       상품A       100.0           김가온
# 1    2019-03-02 15:38:00     상 품 S         NaN           김우찬
# 2    2019-03-02 01:53:00     상 품 A         NaN           김유찬
# 3    2019-03-04 16:39:00       상품Z      2600.0           김재현
# 4    2019-05-03 01:15:00       상품A         NaN           김강현
# ...                  ...       ...         ...           ...
# 2994 2019-04-24 14:12:00       상품Y      2500.0           김정민
# 2995 2019-02-28 15:15:00       상품M      1300.0           김재원
# 2996 2019-02-18 08:16:00       상품Q         NaN           김지율
# 2997 2019-06-05 13:37:00       상품H         NaN           김승주
# 2998 2019-05-16 04:45:00       상품D       400.0           정준기
#
# [2999 rows x 4 columns]

# %%
# item_name에 있는 공백을 제거한다.
# 공백을 제거하는 함수 : strip() -> 문자열의 좌우 공백을 제거 ->
# 현재 데이터에서는 strip() 사용 불가
# 문자열 사이의 공백까지 제거하려면 사용할 함수의 이름은?
# replace(기준문자열, 대체할문자열)
# replace(" ", "")
uriage['item_name'].str.replace(" ","")
# Out:
# 0       상품A
# 1       상품S
# 2       상품A
# 3       상품Z
# 4       상품A
#        ...
# 2994    상품Y
# 2995    상품M
# 2996    상품Q
# 2997    상품H
# 2998    상품D
# Name: item_name, Length: 2999, dtype: object

# %%
def change(x):
    result = x.replace(" ","")
    result = result.lower()
    return result

uriage['item_name'].apply(change)
# Out:
# 0       상품a
# 1       상품s
# 2       상품a
# 3       상품z
# 4       상품a
#        ...
# 2994    상품y
# 2995    상품m
# 2996    상품q
# 2997    상품h
# 2998    상품d
# Name: item_name, Length: 2999, dtype: object

# %%
uriage['item_name'] = uriage['item_name'].apply(lambda x : x.replace(" ","").upper())

# %%
def change(x):
    result = x.replace(" ","")
    result = result.upper()
    return result

uriage['item_name'].apply(change)
# Out:
# 0       상품A
# 1       상품S
# 2       상품A
# 3       상품Z
# 4       상품A
#        ...
# 2994    상품Y
# 2995    상품M
# 2996    상품Q
# 2997    상품H
# 2998    상품D
# Name: item_name, Length: 2999, dtype: object

# %%
# item_name 기준으로 오름차순 정렬
uriage.sort_values("item_name", inplace = True)

# %%
# 인덱스를 초기화 -> 기존의 인덱스는 삭제
uriage.reset_index(drop=True, inplace = True)

# %%
# item_price의 결측치 확인
uriage['item_price'].isna().value_counts()
# Out:
# False    2612
# True      387
# Name: item_price, dtype: int64

# %% [markdown]
# 1. 상품 A의 item_price의 값은 결측치 중 상품 A이면 이 값을 치환
# 2. 나머지 상품들도 같은 작업을 반복

# %%
# 상품 A의 item_price를 출력
# 행의 조건 : 결측치가 아니다 / item_name이 상품 A이다
# 열의 조건 : item_price

# 결측치가 아닌 조건
flg_null = uriage['item_price'].isna()
# df.isna().any(1)

# %%
# 결측치인 값들을 출력
uriage.loc[flg_null]
# Out:
#            purchase_date item_name  item_price customer_name
# 18   2019-01-09 09:24:00       상품A         NaN           김선우
# 22   2019-03-24 09:28:00       상품A         NaN           김은우
# 32   2019-07-17 05:43:00       상품A         NaN           김시우
# 38   2019-01-21 14:06:00       상품A         NaN           김재민
# 44   2019-02-18 06:55:00       상품A         NaN           김서준
# ...                  ...       ...         ...           ...
# 2982 2019-03-03 19:16:00       상품Y         NaN           김하율
# 2984 2019-02-15 03:51:00       상품Y         NaN           김범준
# 2988 2019-02-22 12:09:00       상품Y         NaN           김은혁
# 2994 2019-04-18 07:01:00       상품Y         NaN           김동욱
# 2995 2019-04-08 08:09:00       상품Y         NaN           김하준
#
# [387 rows x 4 columns]

# %%
# item_name이 상품 A인 경우만 출력
uriage.loc[uriage['item_name'] == '상품A']
# Out:
#           purchase_date item_name  item_price customer_name
# 0   2019-01-02 13:26:00       상품A       100.0           김가온
# 1   2019-05-30 03:41:00       상품A       100.0           김시훈
# 2   2019-02-24 11:35:00       상품A       100.0           김유진
# 3   2019-05-07 02:58:00       상품A       100.0           김건희
# 4   2019-02-13 16:37:00       상품A       100.0           김하랑
# ..                  ...       ...         ...           ...
# 134 2019-02-11 22:50:00       상품A       100.0           김시율
# 135 2019-07-19 21:53:00       상품A         NaN           김우찬
# 136 2019-03-02 01:53:00       상품A         NaN           김유찬
# 137 2019-07-14 10:48:00       상품A       100.0           김강현
# 138 2019-03-03 13:01:00       상품A       100.0           김지안
#
# [139 rows x 4 columns]

# %%
# 상품A이고 item_price가 결측치인 경우
uriage.loc[(flg_null) & (uriage['item_name'] == '상품A')]
# Out:
#           purchase_date item_name  item_price customer_name
# 18  2019-01-09 09:24:00       상품A         NaN           김선우
# 22  2019-03-24 09:28:00       상품A         NaN           김은우
# 32  2019-07-17 05:43:00       상품A         NaN           김시우
# 38  2019-01-21 14:06:00       상품A         NaN           김재민
# 44  2019-02-18 06:55:00       상품A         NaN           김서준
# 46  2019-04-30 22:07:00       상품A         NaN           김시환
# 48  2019-03-12 02:05:00       상품A         NaN           김윤찬
# 51  2019-03-23 11:03:00       상품A         NaN           김태인
# 58  2019-04-24 03:18:00       상품A         NaN           김강현
# 59  2019-07-11 02:59:00       상품A         NaN           김시호
# 68  2019-05-22 23:30:00       상품A         NaN           김주원
# 86  2019-01-21 13:05:00       상품A         NaN           김하진
# 96  2019-03-12 19:34:00       상품A         NaN           김진우
# 102 2019-02-13 09:00:00       상품A         NaN           김서윤
# 110 2019-07-18 03:53:00       상품A         NaN           김주혁
# 112 2019-02-01 08:50:00       상품A         NaN           김재준
# 115 2019-01-14 05:59:00       상품A         NaN           김윤호
# 118 2019-05-19 20:22:00       상품A         NaN           김재호
# 128 2019-05-03 01:15:00       상품A         NaN           김강현
# 132 2019-07-05 19:11:00       상품A         NaN           김승훈
# 135 2019-07-19 21:53:00       상품A         NaN           김우찬
# 136 2019-03-02 01:53:00       상품A         NaN           김유찬

# %%
# 상품A이고 item_price가 결측치가 아닌 경우
price = uriage.loc[(uriage['item_name'] == '상품A') & ~(flg_null), 'item_price'].value_counts().index[0]

# %%
# 결측치에 값을 치환하는 함수
# fillna(n) : n의 값으로 결측치를 채운다
uriage.loc[(flg_null) & (uriage['item_name'] == '상품A')].fillna(price)
# Out:
#           purchase_date item_name  item_price customer_name
# 18  2019-01-09 09:24:00       상품A       100.0           김선우
# 22  2019-03-24 09:28:00       상품A       100.0           김은우
# 32  2019-07-17 05:43:00       상품A       100.0           김시우
# 38  2019-01-21 14:06:00       상품A       100.0           김재민
# 44  2019-02-18 06:55:00       상품A       100.0           김서준
# 46  2019-04-30 22:07:00       상품A       100.0           김시환
# 48  2019-03-12 02:05:00       상품A       100.0           김윤찬
# 51  2019-03-23 11:03:00       상품A       100.0           김태인
# 58  2019-04-24 03:18:00       상품A       100.0           김강현
# 59  2019-07-11 02:59:00       상품A       100.0           김시호
# 68  2019-05-22 23:30:00       상품A       100.0           김주원
# 86  2019-01-21 13:05:00       상품A       100.0           김하진
# 96  2019-03-12 19:34:00       상품A       100.0           김진우
# 102 2019-02-13 09:00:00       상품A       100.0           김서윤
# 110 2019-07-18 03:53:00       상품A       100.0           김주혁
# 112 2019-02-01 08:50:00       상품A       100.0           김재준
# 115 2019-01-14 05:59:00       상품A       100.0           김윤호
# 118 2019-05-19 20:22:00       상품A       100.0           김재호
# 128 2019-05-03 01:15:00       상품A       100.0           김강현
# 132 2019-07-05 19:11:00       상품A       100.0           김승훈
# 135 2019-07-19 21:53:00       상품A       100.0           김우찬
# 136 2019-03-02 01:53:00       상품A       100.0           김유찬

# %%
uriage.loc[(flg_null) & (uriage['item_name'] == '상품A'), 'item_price'] = price

# %%
# item_name의 리스트를 출력
name_list = uriage['item_name'].unique()

# %%
for i in name_list:
    # item_price의 값을 구한다
    # item_name이 i와 같고 결측치가 아닌 데이터에서 price를 출력
    price = uriage.loc[~(flg_null) & (uriage['item_name'] == i), 'item_price'].value_counts().index[0]

    # item_namedl i와 같고 결측치인 데이터에서 item_price에 price라는 변수를 삽입
    uriage.loc[(flg_null) & (uriage['item_name'] == i), 'item_price'] = price

# %%
uriage.isna().sum()
# Out:
# purchase_date    0
# item_name        0
# item_price       0
# customer_name    0
# dtype: int64
